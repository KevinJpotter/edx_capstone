# %% [markdown]
# # Module 2
#
# Questions : Which type of complaint should the Department of Housing Preservation and Development of New York City focus on first?

# %% [markdown]
# ### Import Libraries

# %%
from botocore.client import Config
import ibm_boto3
import pandas as pd

# %% [markdown]
# ### Load & Store Data
# Below cells read the data in from the City of New York website url and save as .pkl file on IBM cloud
#
# *Note: Use personal client_cred and bucket*

# %%
# # load csv from given url
df = pd.read_csv("https://data.cityofnewyork.us/resource/fhrw-4uyv.csv?$limit=1000000000&Agency=HPD&$select=created_date,unique_key,complaint_type,incident_zip,incident_address,street_name,address_type,city,resolution_description,borough,latitude,longitude,closed_date,location_type,status")

# convert file to .pkl 
df.to_pickle('./df_raw.pkl')

#upload to cloud for us ein later notebooks
client_cred.upload_file('./df_raw.pkl',bucket,'df_raw_cos.pkl')

# %%
df.shape
# Out:
# (5955140, 15)

# %% [markdown]
# ### Module 2 Review Questions
#
# Question 1 Answer: Heat & Hot Water
#
# Question 2 Answer:  500,863

# %%
df['complaint_type'].value_counts()
# Out:
# HEAT/HOT WATER            1215878
# HEATING                    887869
# PLUMBING                   708151
# GENERAL CONSTRUCTION       500863
# UNSANITARY CONDITION       446863
# PAINT - PLASTER            361257
# PAINT/PLASTER              344588
# ELECTRIC                   305932
# NONCONST                   260890
# DOOR/WINDOW                203362
# WATER LEAK                 191595
# GENERAL                    149678
# FLOORING/STAIRS            136693
# APPLIANCE                  111735
# HPD Literature Request      52830
# SAFETY                      51016
# OUTSIDE BUILDING             7097
# ELEVATOR                     6623
# Unsanitary Condition         5499
# CONSTRUCTION                 5078
# General                      1163
# Safety                        424
# STRUCTURAL                     16
# Plumbing                       11
# AGENCY                          9
# VACANT APARTMENT                8
# Outside Building                6
# ...

# %% [markdown]
# ### Conclusion
#
# Heating & hot water seem to be the biggest issue the department of Housing Preservation & Development is facing
